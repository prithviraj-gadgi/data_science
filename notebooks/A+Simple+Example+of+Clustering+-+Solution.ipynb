# %% [markdown]
# # A Simple Example of Clustering

# %% [markdown]
# You are given much more country data. Using the same methodology as the one in the lecture, group all the countries in 2 clusters.
#
# Try with other numbers of clusters and see if they match your expectations. Maybe 7 is going to be a cool one!
#
# Plot the data using the <i> c </i> parameter to separate the data by the clusters we defined.
#
# <i> Note: c stands for color <i>

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries_exercise.csv'</i>.

# %%
# Load the data
raw_data = pd.read_csv('./../data/Countries-exercise.csv')
# Check the data
raw_data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %% [markdown]
# Remove the duplicate index column from the dataset.

# %%
data = raw_data.copy()

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# ## Select the features

# %% [markdown]
# Create a copy of that data and remove all parameters apart from <i>Longitude</i> and <i>Latitude</i>.

# %%
x = data.iloc[:,1:3]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Here's the actual solution:
#
# Simply change <i> kmeans = KMeans(2) </i> to <i> kmeans = KMeans(3) </i>.
#
# Then run the remaining kernels until the end.

# %%
kmeans = KMeans(7)

# %%
kmeans.fit(x)
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=7)

# %% [markdown]
# ### Clustering Resutls

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([0, 4, 1, 0, 2, 2, 2, 4, 0, 4, 5, 1, 3, 1, 0, 3, 2, 4, 1, 2, 6, 6,
#        4, 2, 4, 0, 0, 2, 0, 2, 0, 0, 0, 0, 0, 3, 4, 1, 6, 2, 0, 3, 6, 6,
#        1, 6, 5, 0, 1, 6, 0, 0, 0, 0, 4, 4, 2, 2, 4, 0, 2, 0, 6, 0, 4, 4,
#        2, 2, 4, 2, 3, 0, 2, 2, 3, 6, 2, 4, 2, 6, 6, 6, 6, 6, 2, 0, 2, 0,
#        3, 0, 3, 1, 0, 2, 0, 2, 3, 2, 4, 3, 1, 2, 4, 4, 2, 4, 2, 0, 2, 4,
#        3, 4, 4, 1, 4, 3, 0, 0, 3, 2, 4, 3, 4, 6, 2, 0, 2, 4, 1, 2, 2, 2,
#        3, 0, 6, 2, 2, 1, 4, 0, 3, 2, 6, 2, 3, 2, 3, 3, 1, 6, 0, 1, 1, 3,
#        1, 3, 6, 3, 6, 0, 5, 2, 2, 4, 3, 3, 4, 4, 0, 5, 0, 3, 3, 3, 2, 0,
#        3, 2, 0, 4, 5, 4, 2, 4, 1, 6, 4, 4, 1, 6, 3, 0, 6, 3, 6, 0, 2, 4,
#        1, 0, 2, 6, 0, 2, 2, 2, 1, 0, 1, 4, 0, 6, 6, 3, 4, 4, 3, 5, 0, 2,
#        4, 3, 1, 1, 2, 0, 0, 4, 2, 0, 0, 0, 0, 3, 3, 5, 5, 4, 1, 1, 1])

# %%
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
#              name   Longitude   Latitude  Cluster
# 0           Aruba  -69.982677  12.520880        0
# 1     Afghanistan   66.004734  33.835231        4
# 2          Angola   17.537368 -12.293361        1
# 3        Anguilla  -63.064989  18.223959        0
# 4         Albania   20.049834  41.142450        2
# ..            ...         ...        ...      ...
# 236         Samoa -172.164851 -13.753243        5
# 237         Yemen   47.586762  15.909280        4
# 238  South Africa   25.083901 -29.000341        1
# 239        Zambia   27.774759 -13.458242        1
# 240      Zimbabwe   29.851441 -19.004204        1
#
# [241 rows x 4 columns]

# %%
plt.scatter(data['Longitude'], data['Latitude'],c=data_with_clusters['Cluster'], cmap = 'rainbow')
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()
