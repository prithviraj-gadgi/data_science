# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('./../data/Dummies.csv')

# %%
data.head()
# Out:
#     SAT   GPA Attendance
# 0  1714  2.40         No
# 1  1664  2.52         No
# 2  1760  2.54         No
# 3  1685  2.74         No
# 4  1693  2.83         No

# %%
data['Attendance'] = data['Attendance'].map({'No': 0, 'Yes': 1})

# %%
data.head()
# Out:
#     SAT   GPA  Attendance
# 0  1714  2.40           0
# 1  1664  2.52           0
# 2  1760  2.54           0
# 3  1685  2.74           0
# 4  1693  2.83           0

# %%
data.describe()
# Out:
#                SAT        GPA  Attendance
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    0.464286
# std     104.530661   0.271617    0.501718
# min    1634.000000   2.400000    0.000000
# 25%    1772.000000   3.190000    0.000000
# 50%    1846.000000   3.380000    0.000000
# 75%    1934.000000   3.502500    1.000000
# max    2050.000000   3.810000    1.000000

# %%
y = data['GPA']
x1 = data[['SAT', 'Attendance']]

# %%
x = sm.add_constant(x1)
result = sm.OLS(y, x).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GPA   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     52.70
# Date:                Wed, 08 Jan 2025   Prob (F-statistic):           2.19e-15
# Time:                        05:14:03   Log-Likelihood:                 25.798
# No. Observations:                  84   AIC:                            -45.60
# Df Residuals:                      81   BIC:                            -38.30
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6439      0.358      1.797      0.076      -0.069       1.357
# SAT            0.0014      0.000      7.141      0.000       0.001       0.002
# Attendance     0.2226      0.041      5.451      0.000       0.141       0.304
# ==============================================================================
# Omnibus:                       19.560   Durbin-Watson:                   1.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.189
# Skew:                          -1.028   Prob(JB):                     1.25e-06
# Kurtosis:                       4.881   Cond. No.                     3.35e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(data['SAT'], data['GPA'], c=data['Attendance'],cmap='RdYlGn')
yhat_yes = 0.8665 + 0.0014*data['SAT']
yhat_no = 0.6439 + 0.0014*data['SAT']
yhat = 0.275 + 0.0017*data['SAT']
plt.plot(data['SAT'], yhat_yes, lw=2, c='green', label='Regression Line for Attendance Yes')
plt.plot(data['SAT'], yhat_no, lw=2, c='red', label='Regression Line for Attendance No')
plt.plot(data['SAT'], yhat, lw=2, c='blue', label='Regression Line Without Attendance')
plt.xlabel('SAT', fontdict={'size': 14, 'weight': 'bold'})
plt.ylabel('GPA', fontdict={'size': 14, 'weight': 'bold'})
plt.legend()
plt.show()

# %%
x
# Out:
#     const   SAT  Attendance
# 0     1.0  1714           0
# 1     1.0  1664           0
# 2     1.0  1760           0
# 3     1.0  1685           0
# 4     1.0  1693           0
# ..    ...   ...         ...
# 79    1.0  1936           1
# 80    1.0  1810           1
# 81    1.0  1987           0
# 82    1.0  1962           1
# 83    1.0  2050           1
#
# [84 rows x 3 columns]

# %%
new_data = pd.DataFrame({'const': 1, 'SAT': [1700, 1650], 'Attendance': [0, 1]})
new_data
# Out:
#    const   SAT  Attendance
# 0      1  1700           0
# 1      1  1650           1

# %%
new_data = new_data.rename(index={0: 'Alice', 1: 'Bob'})
new_data
# Out:
#        const   SAT  Attendance
# Alice      1  1700           0
# Bob        1  1650           1

# %%
prediction = result.predict(new_data)
prediction
# Out:
# Alice    3.023513
# Bob      3.176167
# dtype: float64

# %%
prediction_df = pd.DataFrame({'GPA': prediction})
new_data.join(prediction_df)
# Out:
#        const   SAT  Attendance       GPA
# Alice      1  1700           0  3.023513
# Bob        1  1650           1  3.176167
