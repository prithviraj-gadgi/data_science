# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('./../data/iris_dataset.csv')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
data.shape
# Out:
# (150, 4)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.scatter(data['sepal_length'], data['sepal_width'])
ax1.set_title('Sepal Length and Sepal Width')
ax2.scatter(data['petal_length'], data['petal_width'])
ax2.set_title('Petal Length and Petal Width')
plt.show()

# %%
x = data.copy()
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
clusters = kmeans.fit_predict(x)
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.scatter(data['sepal_length'], data['sepal_width'], c=clusters, cmap='rainbow')
ax1.set_title('Sepal Length and Sepal Width')
ax2.scatter(data['petal_length'], data['petal_width'], c=clusters, cmap='rainbow')
ax2.set_title('Petal Length and Petal Width')
plt.show()

# %%
x_scaled = preprocessing.scale(x)
kmeans = KMeans(2)
kmeans.fit(x_scaled)
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
clusters = kmeans.fit_predict(x_scaled)
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.scatter(data['sepal_length'], data['sepal_width'], c=clusters, cmap='rainbow')
ax1.set_title('Sepal Length and Sepal Width')
ax2.scatter(data['petal_length'], data['petal_width'], c=clusters, cmap='rainbow')
ax2.set_title('Petal Length and Petal Width')
plt.show()

# %%
wcss = []
cl_num = range(1, 10)
for i in cl_num:
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
plt.plot(cl_num, wcss)
plt.xlabel('Number of Clusters')
plt.ylabel('Within Cluster Sum of Squares')
plt.show()

# %%
kmeans = KMeans(3)
kmeans.fit(x_scaled)
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
clusters = kmeans.fit_predict(x_scaled)
# Out:
# C:\Users\prith\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.scatter(data['sepal_length'], data['sepal_width'], c=clusters, cmap='rainbow')
ax1.set_title('Sepal Length and Sepal Width')
ax2.scatter(data['petal_length'], data['petal_width'], c=clusters, cmap='rainbow')
ax2.set_title('Petal Length and Petal Width')
plt.show()

# %%
real_data = pd.read_csv('./../data/iris_with_answers.csv')

# %%
real_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
real_data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
real_data['species'] = real_data['species'].map({'setosa':0, 'versicolor':1 , 'virginica':2})

# %%
real_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
f, axes = plt.subplots(2, 2, figsize=(10,8))
ax1, ax2, ax3, ax4 = axes.flatten()
ax1.scatter(data['sepal_length'], data['sepal_width'], c=clusters, cmap='rainbow')
ax1.set_title('Sepal Length and Sepal Width (From Data)')
ax2.scatter(data['petal_length'], data['petal_width'], c=clusters, cmap='rainbow')
ax2.set_title('Petal Length and Petal Width (From Data)')
ax3.scatter(real_data['sepal_length'], real_data['sepal_width'], c=real_data['species'], cmap='rainbow')
ax3.set_title('Sepal Length and Sepal Width (From Real Data)')
ax4.scatter(real_data['petal_length'], real_data['petal_width'], c=real_data['species'], cmap='rainbow')
ax4.set_title('Petal Length and Petal Width (From Real Data)')
plt.tight_layout()
plt.show()
